# %% [markdown]
# <a href="https://colab.research.google.com/github/Atik07/practical-machine-learning/blob/main/PCA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# import random as rd

import matplotlib.pyplot as plt

# %%
import sklearn
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn import preprocessing

# %%
import tensorflow as tf
from tensorflow import keras
import cv2
import math

# %%
# %matplotlib inline

# %%
sk_mnist = sklearn.datasets.load_digits()

# %%
sk_data = sk_mnist.data

# %%
tf_mnist = tf.keras.datasets.mnist.load_data()

# %%
(x_train, y_train), (x_test, y_test) = tf_mnist

# %%
type(sk_data)
# Out:
# numpy.ndarray

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
sk_data.max()
# Out:
# 16.0

# %%
 max= 255.0
 min= 0.0
 
 delta = max-min

 x_train = x_train/delta
 x_test = x_test/delta

# %%
max1=sk_data.max()

min1=0.0
delta1 = max1-min1

sk_data = sk_data/delta1

# %%
sk_data
# Out:
# array([[0.    , 0.    , 0.3125, ..., 0.    , 0.    , 0.    ],
#        [0.    , 0.    , 0.    , ..., 0.625 , 0.    , 0.    ],
#        [0.    , 0.    , 0.    , ..., 1.    , 0.5625, 0.    ],
#        ...,
#        [0.    , 0.    , 0.0625, ..., 0.375 , 0.    , 0.    ],
#        [0.    , 0.    , 0.125 , ..., 0.75  , 0.    , 0.    ],
#        [0.    , 0.    , 0.625 , ..., 0.75  , 0.0625, 0.    ]])

# %%
type(sk_data)
# Out:
# numpy.ndarray

# %%
pca=PCA()

# %%
pca.fit(sk_data)
pca_data = pca.transform(sk_data)

# %%
per_var = np.round(pca.explained_variance_ratio_*64, decimals=1) 
labels = ['PC' + str(x) for x in range(1, len(per_var)+1)]
plt.bar(x=range(1, len(per_var)+1), height=per_var, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')           
plt.xlabel('Principal Component')
plt.title('Scree Plot')
plt.show()

# %%
pca_df = pd.DataFrame(pca_data, columns=labels)
plt.scatter(pca_df.PC1, pca_df.PC2)
plt.title('PCA GRAPH_SK_DATA')
plt.xlabel('PC1 - {0}%'.format(per_var[0]))
plt.ylabel('PC2 - {0}%'.format(per_var[1]))
# Out:
# Text(0, 0.5, 'PC2 - 8.7%')

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
ax.scatter(pca_df.PC1, pca_df.PC2, pca_df.PC3)

# plt.scatter(pca_df.PC1, pca_df.PC2)
# ax.title('PCA 3-Principal Components GRAPH_SK_DATA')
ax.set_xlabel('PC1 - {0}%'.format(per_var[0]))
ax.set_ylabel('PC2 - {0}%'.format(per_var[1]))
ax.set_zlabel('PC3 - {0}%'.format(per_var[2]))

plt.show()
